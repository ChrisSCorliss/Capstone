# %% [markdown]
# # TES Salary Stats Rank

# %%
import pandas as pd

# %%
salary = pd.read_csv('../Capstone_csv_file/salary_edited_to_fit_17-18')

# %%
rbs = pd.read_csv('../Capstone_csv_file/tes_stats_rank_17-18')

rbs.set_index('NAME', inplace = True)

rbs_final_salary = rbs.merge(salary, on = 'NAME')

rbs_final_salary.set_index('NAME', inplace = True)

# %%
rbs_final_salary.head()
# Out:
#                 TGT  REC  TGT/G   YDS  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Rob Gronkowski  105   69    7.5  1084         3    204.7   8    53    1     0
# Greg Olsen       38   17    5.4   191         1     60.9   1    30    0     0
# Travis Kelce    122   83    8.1  1038         4    177.0   8    44    0     0
# Jimmy Graham     95   57    5.9   520         0    123.8  10    33    0     0
# Delanie Walker  111   74    6.9   807         0    173.9   3    42    2     2
#
#                 ...  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME            ...
# Rob Gronkowski  ...       5.0         4.0            2.0           2.0
# Greg Olsen      ...      44.5        12.5            7.0          60.0
# Travis Kelce    ...       1.0         1.0            1.0          11.0
# Jimmy Graham    ...       9.5         7.0           38.5          32.0
# Delanie Walker  ...       3.5         6.0           38.5          12.0
#
# ...

# %%
rbs_final_salary.to_csv('../Capstone_csv_file/tes_stats_salary_17-18')
