# %% [markdown]
# # TES Salary Stats Rank

# %%
import pandas as pd

# %%
salary = pd.read_csv('../Capstone_csv_file/salary_edited_to_fit_19-20')

# %%
rbs = pd.read_csv('../Capstone_csv_file/tes_stats_rank_19-20')

rbs.set_index('NAME', inplace = True)

rbs_final_salary = rbs.merge(salary, on = 'NAME')

rbs_final_salary.set_index('NAME', inplace = True)

# %%
rbs_final_salary.head()
# Out:
#                 TGT  REC  TGT/G   YDS  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Travis Kelce    136   97    8.5  1229         2     12.7   5    47    1     1
# Delanie Walker   31   21    4.4   215         0     10.2   2    29    1     0
# Zach Ertz       135   88    9.0   916         1     10.4   6    30    1     1
# Jared Cook       65   43    4.6   705         0     16.4   9    61    0     0
# Greg Olsen       82   52    5.9   597         1     11.5   2    41    0     0
#
#                 ...  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME            ...
# Travis Kelce    ...       1.0         2.5            6.0          10.5
# Delanie Walker  ...      41.5        23.0           39.5          37.5
# Zach Ertz       ...       3.0         1.0           11.5          35.0
# Jared Cook      ...      15.0        20.0           39.5           1.5
# Greg Olsen      ...      11.0         9.5           11.5          22.5
#
# ...

# %%
rbs_final_salary.to_csv('../Capstone_csv_file/tes_stats_salary_19-20')
