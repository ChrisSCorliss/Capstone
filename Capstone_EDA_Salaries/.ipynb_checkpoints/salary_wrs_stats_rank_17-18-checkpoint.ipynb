# %% [markdown]
# # WRS Salary Stats Rank

# %%
import pandas as pd

# %%
salary = pd.read_csv('../Capstone_csv_file/salary_edited_to_fit_17-18')

# %%
rbs = pd.read_csv('../Capstone_csv_file/wrs_stats_rank_17-18')

rbs.set_index('NAME', inplace = True)

rbs_final_salary = rbs.merge(salary, on = 'NAME')

rbs_final_salary.set_index('NAME', inplace = True)

# %%
rbs_final_salary.head()
# Out:
#                   TGT  REC  TGT/G   YDS  100+ YDS  YDS/REC  TD  LONG  FUM  \
# NAME
# Antonio Brown     162  101   11.6  1533         8    204.7   9    57    4
# Julio Jones       148   88    9.2  1444         4    260.2   3    53    0
# Larry Fitzgerald  161  109   10.1  1156         4    160.9   6    37    1
# Doug Baldwin      116   75    7.2   991         2    220.7   8    54    0
# Brandin Cooks     114   65    7.1  1082         2    278.3   7    64    0
#
#                   FUML  ...  REC_rank  TGT/G_rank  100+ YDS_rank  \
# NAME                    ...
# Antonio Brown        0  ...       5.0         1.5            1.0
# Julio Jones          0  ...       9.0         8.0            6.0
# Larry Fitzgerald     1  ...       2.0         4.5            6.0
# Doug Baldwin         0  ...      12.0        23.5           21.0
# Brandin Cooks        0  ...      20.5        26.0           21.0
#
#                   YDS/REC_rank  TD_rank  LONG_rank  FUM_rank  FUML_rank  \
# NAME
# ...

# %%
rbs_final_salary.to_csv('../Capstone_csv_file/wrs_stats_salary_17-18')
