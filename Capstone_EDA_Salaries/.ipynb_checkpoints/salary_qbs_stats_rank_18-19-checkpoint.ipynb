# %% [markdown]
# # QBS Salary Stats Rank

# %%
import pandas as pd

# %%
salary = pd.read_csv('../Capstone_csv_file/salary_edited_to_fit_18-19')

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19')

qbs.set_index('NAME', inplace = True)

qbs_final_salary = qbs.merge(salary, on = 'NAME')

qbs_final_salary.set_index('NAME', inplace = True)

# %%
qbs_final_salary.head()
# Out:
#                 COMP  ATT  ATT/G   YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Josh Johnson      52   91   22.8   590         0   57.1      6.5      11.3
# Jameis Winston   244  378   34.4  2992         5   64.6      7.9      12.3
# Derek Anderson    42   70   35.0   465         0   60.0      6.6      11.1
# Carson Wentz     279  401   36.5  3074         5   69.6      7.7      11.0
# Mark Sanchez      19   35   17.5   138         0   54.3      3.9       7.3
#
#                 TD  INT  ...  YDS/ATT_rank  YDS/COMP_rank  TD_rank  INT_rank  \
# NAME                     ...
# Josh Johnson     3    4  ...          42.0           22.5     42.0      18.0
# Jameis Winston  19   14  ...          13.0           10.5     21.5      50.0
# Derek Anderson   0    4  ...          39.0           28.5     54.0      18.0
# Carson Wentz    21    7  ...          14.5           31.0     18.5      27.0
# Mark Sanchez     0    3  ...          54.0           54.0     54.0      12.0
#
#                 QBR_rank  LONG_rank  SACKS_rank  SACK YDS_rank  FUML_rank  \
# NAME
# Josh Johnson        29.0        9.0        14.0           15.0        8.5
# Jameis Winston      25.0       31.5        35.0           31.5       40.0
# Derek Anderson      52.0       47.0         6.5            5.5       31.0
# Carson Wentz        27.0       35.5        39.5           37.0       52.5
# Mark Sanchez        53.0       54.0        11.0           13.0        8.5
#
#                  salary
# NAME
# Josh Johnson     915000
# Jameis Winston  6337819
# Derek Anderson  1073530
# Carson Wentz    6669085
# Mark Sanchez     915000
#
# [5 rows x 31 columns]

# %%
qbs_final_salary.to_csv('../Capstone_csv_file/qbs_stats_salary_18-19')
