# %% [markdown]
# # WRS Salary Stats Rank

# %%
import pandas as pd

# %%
salary = pd.read_csv('../Capstone_csv_file/salary_edited_to_fit_18-19')

# %%
rbs = pd.read_csv('../Capstone_csv_file/wrs_stats_rank_18-19')

rbs.set_index('NAME', inplace = True)

rbs_final_salary = rbs.merge(salary, on = 'NAME')

rbs_final_salary.set_index('NAME', inplace = True)

# %%
rbs_final_salary.head()
# Out:
#                  TGT  REC  TGT/G  YDS  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Curtis Samuel     65   39    5.0  494         0     12.7   5    53    1     1
# Will Fuller       45   32    6.4  503         3     15.7   4    73    0     0
# Alshon Jeffery    92   65    7.1  843         2     13.0   6    52    1     0
# Martavis Bryant   27   19    3.4  266         0     14.0   0    47    1     1
# Julian Edelman   108   74    9.0  850         2     11.5   6    36    1     0
#
#                  ...  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME             ...
# Curtis Samuel    ...      64.5        68.0          106.5          70.5
# Will Fuller      ...      81.0        35.5           20.0          18.0
# Alshon Jeffery   ...      30.0        24.5           32.0          62.5
# Martavis Bryant  ...     115.5       100.0          106.5          44.0
# Julian Edelman   ...      20.5        11.0           32.0          98.0
#
# ...

# %%
rbs_final_salary.to_csv('../Capstone_csv_file/wrs_stats_salary_18-19')
