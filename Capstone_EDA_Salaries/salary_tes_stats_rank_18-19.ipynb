# %% [markdown]
# # TES Salary Stats Rank

# %%
import pandas as pd

# %%
salary = pd.read_csv('../Capstone_csv_file/salary_edited_to_fit_18-19')

# %%
rbs = pd.read_csv('../Capstone_csv_file/tes_stats_rank_18-19')

rbs.set_index('NAME', inplace = True)

rbs_final_salary = rbs.merge(salary, on = 'NAME')

rbs_final_salary.set_index('NAME', inplace = True)

# %%
rbs_final_salary.head()
# Out:
#                   TGT  REC  TGT/G   YDS  100+ YDS  YDS/REC  TD  LONG  FUM  \
# NAME
# Demetrius Harris   25   12    1.7   164         0     13.7   3    35    0
# Hayden Hurst       23   13    1.9   163         0     12.5   1    32    0
# Vance McDonald     73   50    4.9   610         1     12.2   4    75    2
# Rob Gronkowski     72   47    5.5   682         2     14.5   3    42    1
# Travis Kelce      150  103    9.4  1336         5     13.0  10    43    2
#
#                   FUML  ...  REC_rank  TGT/G_rank  100+ YDS_rank  \
# NAME                    ...
# Demetrius Harris     0  ...      58.5        51.5           37.5
# Hayden Hurst         0  ...      55.5        48.5           37.5
# Vance McDonald       1  ...      12.0        14.0            9.0
# Rob Gronkowski       1  ...      13.0        11.0            5.0
# Travis Kelce         1  ...       2.0         2.0            1.5
#
#                   YDS/REC_rank  TD_rank  LONG_rank  FUM_rank  FUML_rank  \
# NAME
# ...

# %%
rbs_final_salary.to_csv('../Capstone_csv_file/tes_stats_salary_18-19')
