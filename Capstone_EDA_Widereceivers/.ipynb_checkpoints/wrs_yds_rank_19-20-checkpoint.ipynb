# %% [markdown]
# # Widereceivers Fum Rank

# %%
import pandas as pd

# %%
wrs = pd.read_csv('../Capstone_csv_file/wrs_stats_rank_19-20', index_col = 'NAME')

# %%
wrs.head()
# Out:
#                TGT  REC  TGT/G  YDS  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Vyncint Smith   31   17    2.4  225         0     13.2   0    37    1     1
# Golden Tate     85   49    7.7  676         1     13.8   6    64    1     1
# Malik Turner    22   15    1.6  245         0     16.3   1    33    0     0
# Allen Lazard    52   35    4.3  477         1     13.6   3    43    0     0
# Auden Tate      81   40    6.8  575         0     14.4   1    33    1     1
#
#                ...  TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  \
# NAME           ...
# Vyncint Smith  ...     112.0     114.0       115.0          102.5
# Golden Tate    ...      45.0      49.0        22.5           57.0
# Malik Turner   ...     127.5     119.5       128.0          102.5
# Allen Lazard   ...      79.5      71.0        77.5           57.0
# Auden Tate     ...      50.5      65.0        36.5          102.5
#
#                YDS/REC_rank  TD_rank  LONG_rank  FUM_rank  FUML_rank  overall
# ...

# %%
wrs = wrs[['YDS', 'YDS_rank']]

# %%
wrs = wrs.sort_values('YDS_rank')

# %%
wrs.head()
# Out:
#                  YDS  YDS_rank
# NAME
# Michael Thomas  1725       1.0
# Julio Jones     1394       2.0
# Chris Godwin    1333       3.0
# Devante Parker  1202       4.0
# Keenan Allen    1199       5.0

# %%
wrs.to_csv('../Capstone_csv_file/wrs_yds_rank_19-20')
