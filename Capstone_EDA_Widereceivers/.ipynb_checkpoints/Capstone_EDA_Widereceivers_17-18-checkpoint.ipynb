# %% [markdown]
# # Widereceiver EDA

# %%
import pandas as pd

# %%
wrs = pd.read_csv('../Capstone_Scrapping/Capstone_text_files/wide_receiver_17-18.txt')

# %%
wrs
# Out:
#                  NAME  RTG TEAM  GP  TGT  REC  TGT/G    YDS  100+ YDS  \
# 0       Antonio Brown   99  PIT  14  162  101   11.6  1,533         8
# 1         Julio Jones   97  ATL  16  148   88    9.2  1,444         4
# 2    Odell Beckham Jr   97  NYG   4   41   25   10.2    302         0
# 3    Larry Fitzgerald   85  ARI  16  161  109   10.1  1,156         4
# 4            AJ Green   91  CIN  16  144   75    9.0  1,078         3
# ..                ...  ...  ...  ..  ...  ...    ...    ...       ...
# 221      Griff Whalen   60  BAL   2    6    4    3.0     23         0
# 222    Travis Rudolph   60  NYG   7   21    8    3.0    101         0
# 223    Marcus Johnson   60  PHI  10    8    5    0.8     45         0
# 224   Kendrick Bourne   77   SF  11   34   16    3.1    257         0
# 225        Andy Jones   58  DET   3    0    0    0.0      0         0
#
#      YDS/REC  TD  LONG  FUM  FUML
# 0      204.7   9    57    4     0
# 1      260.2   3    53    0     0
# 2       50.1   3    48    0     0
# 3      160.9   6    37    1     1
# 4      217.1   8    77    2     2
# ..       ...  ..   ...  ...   ...
# 221      5.8   0     9    0     0
# 222     57.0   0    29    0     0
# 223     29.7   0    16    1     1
# 224    106.2   0    54    0     0
# 225      0.0   0     0    0     0
#
# [226 rows x 14 columns]

# %%
wrs['YDS'] = wrs['YDS'].str.replace(',', '').astype('int64')

# %%
wrs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
wrs = wrs[wrs['TGT'] > 16].copy()

# %%
wrs
# Out:
#                  NAME  RTG TEAM  GP  TGT  REC  TGT/G   YDS  100+ YDS  YDS/REC  \
# 0       Antonio Brown   99  PIT  14  162  101   11.6  1533         8    204.7
# 1         Julio Jones   97  ATL  16  148   88    9.2  1444         4    260.2
# 2    Odell Beckham Jr   97  NYG   4   41   25   10.2   302         0     50.1
# 3    Larry Fitzgerald   85  ARI  16  161  109   10.1  1156         4    160.9
# 4            AJ Green   91  CIN  16  144   75    9.0  1078         3    217.1
# ..                ...  ...  ...  ..  ...  ...    ...   ...       ...      ...
# 206      Bryce Treggs   62  CLE   6   18    5    3.0    79         0     65.0
# 209     Johnny Holton   62  OAK  16   18    9    1.1   218         0    156.5
# 213      Damiere Byrd   72  CAR   8   17   10    2.1   105         0     58.7
# 222    Travis Rudolph   60  NYG   7   21    8    3.0   101         0     57.0
# 224   Kendrick Bourne   77   SF  11   34   16    3.1   257         0    106.2
#
#      TD  LONG  FUM  FUML
# 0     9    57    4     0
# 1     3    53    0     0
# 2     3    48    0     0
# 3     6    37    1     1
# 4     8    77    2     2
# ..   ..   ...  ...   ...
# 206   0    20    1     1
# 209   3    64    3     2
# 213   2    31    0     0
# 222   0    29    0     0
# 224   0    54    0     0
#
# [139 rows x 14 columns]

# %%
wrs = wrs.groupby('NAME', sort = False).mean()

# %%
wrs.drop(columns = ['RTG', 'GP'], axis = 1, inplace = True)

# %%
wrs_stats = wrs.copy()

# %%
wrs_rank = {}

# %%
wrs_rank['YDS_rank'] = wrs['YDS'].rank(ascending = False)

# %%
wrs_rank['TGT_rank'] = wrs['TGT'].rank(ascending = False)

# %%
wrs_rank['REC_rank'] = wrs['REC'].rank(ascending = False)

# %%
wrs_rank['TGT/G_rank'] = wrs['TGT/G'].rank(ascending = False)

# %%
wrs_rank['100+ YDS_rank'] = wrs['100+ YDS'].rank(ascending = False)

# %%
wrs_rank['YDS/REC_rank'] = wrs['YDS/REC'].rank(ascending = False)

# %%
wrs_rank['TD_rank'] = wrs['TD'].rank(ascending = False)

# %%
wrs_rank['LONG_rank'] = wrs['LONG'].rank(ascending = False)

# %%
wrs_rank['FUM_rank'] = wrs['FUM'].rank()

# %%
wrs_rank['FUML_rank'] = wrs['FUML'].rank()

# %%
wrs_rank['overall'] = (wrs_rank['TGT_rank'] + wrs_rank['REC_rank'] + wrs_rank['TGT/G_rank'] + wrs_rank['100+ YDS_rank'] +
            wrs_rank['YDS/REC_rank'] + wrs_rank['TD_rank'] + wrs_rank['LONG_rank'] +
            wrs_rank['FUM_rank'] + wrs_rank['FUML_rank'] + wrs_rank['YDS_rank'])/10

# %%
wrs_rank = pd.DataFrame(wrs_rank)

# %%
wrs_final_rank = {}

# %%
wrs_final_rank['final_rank'] = wrs_rank['overall'].rank()

# %%
wrs_final_rank = pd.DataFrame(wrs_final_rank)

# %%
wrs_final_rank = wrs_final_rank.sort_values('final_rank')

# %%
wrs_final_rank.to_csv('../Capstone_csv_file/wrs_final_rank_17-18')

# %%
wrs = wrs_stats.merge(wrs_rank, on = 'NAME')

# %%
wrs.to_csv('../Capstone_csv_file/wrs_stats_rank_17-18')

# %%
wrs
# Out:
#                   TGT  REC  TGT/G   YDS  100+ YDS  YDS/REC  TD  LONG  FUM  \
# NAME
# Antonio Brown     162  101   11.6  1533         8    204.7   9    57    4
# Julio Jones       148   88    9.2  1444         4    260.2   3    53    0
# Odell Beckham Jr   41   25   10.2   302         0     50.1   3    48    0
# Larry Fitzgerald  161  109   10.1  1156         4    160.9   6    37    1
# AJ Green          144   75    9.0  1078         3    217.1   8    77    2
# ...               ...  ...    ...   ...       ...      ...  ..   ...  ...
# Bryce Treggs       18    5    3.0    79         0     65.0   0    20    1
# Johnny Holton      18    9    1.1   218         0    156.5   3    64    3
# Damiere Byrd       17   10    2.1   105         0     58.7   2    31    0
# Travis Rudolph     21    8    3.0   101         0     57.0   0    29    0
# Kendrick Bourne    34   16    3.1   257         0    106.2   0    54    0
#
#                   FUML  ...  TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  \
# NAME                    ...
# Antonio Brown        0  ...       2.0       5.0         1.5            1.0
# Julio Jones          0  ...       7.0       9.0         8.0            6.0
# Odell Beckham Jr     0  ...      96.0      89.0         3.0           99.5
# Larry Fitzgerald     1  ...       3.5       2.0         4.5            6.0
# AJ Green             2  ...       8.0      12.0        10.0           12.0
# ...                ...  ...       ...       ...         ...            ...
# Bryce Treggs         1  ...     132.5     137.5       104.0           99.5
# Johnny Holton        2  ...     132.5     132.5       139.0           99.5
# Damiere Byrd         0  ...     137.0     130.0       121.5           99.5
# Travis Rudolph       0  ...     127.0     134.5       104.0           99.5
# Kendrick Bourne      0  ...     108.0     116.0       101.5           99.5
#
#                   YDS/REC_rank  TD_rank  LONG_rank  FUM_rank  FUML_rank  \
# NAME
# Antonio Brown             34.0      4.5       41.0     135.5       54.0
# Julio Jones                5.0     57.0       54.5      40.5       54.0
# Odell Beckham Jr         134.0     57.0       67.5      40.5       54.0
# Larry Fitzgerald          57.0     23.0       97.0      98.5      118.5
# AJ Green                  24.0     10.0        7.5     122.0      133.5
# ...                        ...      ...        ...       ...        ...
# Bryce Treggs             124.0    127.5      131.5      98.5      118.5
# Johnny Holton             62.0     57.0       24.5     130.5      133.5
# Damiere Byrd             127.0     79.0      108.5      40.5       54.0
# Travis Rudolph           128.0    127.5      115.0      40.5       54.0
# Kendrick Bourne          101.0    127.5       49.0      40.5       54.0
#
#                   overall
# NAME
# Antonio Brown       27.95
# Julio Jones         24.30
# Odell Beckham Jr    73.45
# Larry Fitzgerald    41.80
# AJ Green            35.00
# ...                   ...
# Bryce Treggs       120.75
# Johnny Holton      102.10
# Damiere Byrd       102.40
# Travis Rudolph     105.90
# Kendrick Bourne     89.70
#
# [139 rows x 21 columns]
