# %% [markdown]
# # Widereceivers TD Rank

# %%
import pandas as pd

# %%
wrs = pd.read_csv('../Capstone_csv_file/wrs_stats_rank_18-19', index_col = 'NAME')

# %%
wrs.head()
# Out:
#                 TGT  REC  TGT/G  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Curtis Samuel    65   39    5.0         0     12.7   5    53    1     1
# Keke Coutee      41   28    6.8         1     10.2   1    40    0     0
# Devante Parker   47   24    4.3         1     12.9   1    46    0     0
# Keith Kirkwood   21   13    2.6         0     16.1   2    42    0     0
# Michael Floyd    24   10    1.8         0     10.0   1    20    0     0
#
#                 TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME
# Curtis Samuel       65.5      64.5        68.0          106.5          70.5
# Keke Coutee        100.5      88.5        30.5           53.5         119.0
# Devante Parker      86.0      99.5        81.0           53.5          64.5
# Keith Kirkwood     138.0     134.5       120.0          106.5          15.0
# Michael Floyd      133.5     142.5       133.0          106.5         124.0
#
# ...

# %%
wrs = wrs[['TD', 'TD_rank']]

# %%
wrs = wrs.sort_values('TD_rank')

# %%
wrs.head()
# Out:
#                  TD  TD_rank
# NAME
# Antonio Brown    15      1.0
# Davante Adams    13      2.0
# Tyreek Hill      12      3.0
# DeAndre Hopkins  11      4.0
# Mike Williams    10      6.0

# %%
wrs.to_csv('../Capstone_csv_file/wrs_td_rank_18-19')
