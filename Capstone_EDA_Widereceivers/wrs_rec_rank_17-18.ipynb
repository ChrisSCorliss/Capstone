# %% [markdown]
# # Widereceivers Rec Rank

# %%
import pandas as pd

# %%
wrs = pd.read_csv('../Capstone_csv_file/wrs_stats_rank_17-18', index_col = 'NAME')

# %%
wrs.head()
# Out:
#                   TGT  REC  TGT/G  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Antonio Brown     162  101   11.6         8    204.7   9    57    4     0
# Julio Jones       148   88    9.2         4    260.2   3    53    0     0
# Odell Beckham Jr   41   25   10.2         0     50.1   3    48    0     0
# Larry Fitzgerald  161  109   10.1         4    160.9   6    37    1     1
# AJ Green          144   75    9.0         3    217.1   8    77    2     2
#
#                   TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME
# Antonio Brown          2.0       5.0         1.5            1.0          34.0
# Julio Jones            7.0       9.0         8.0            6.0           5.0
# Odell Beckham Jr      96.0      89.0         3.0           99.5         134.0
# Larry Fitzgerald       3.5       2.0         4.5            6.0          57.0
# AJ Green               8.0      12.0        10.0           12.0          24.0
#
# ...

# %%
wrs = wrs[['REC', 'REC_rank']]

# %%
wrs = wrs.sort_values('REC_rank')

# %%
wrs.head()
# Out:
#                   REC  REC_rank
# NAME
# Jarvis Landry     112       1.0
# Larry Fitzgerald  109       2.0
# Michael Thomas    104       3.0
# Keenan Allen      102       4.0
# Antonio Brown     101       5.0

# %%
wrs.to_csv('../Capstone_csv_file/wrs_rec_rank_17-18')
