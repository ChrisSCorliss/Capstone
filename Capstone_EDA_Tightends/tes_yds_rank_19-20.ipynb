# %% [markdown]
# # Tightends Yds Rank

# %%
import pandas as pd

# %%
tes = pd.read_csv('../Capstone_csv_file/tes_stats_rank_19-20', index_col = 'NAME')

# %%
tes.head()
# Out:
#                  TGT  REC  TGT/G   YDS  100+ YDS  YDS/REC  TD  LONG  FUM  \
# NAME
# Jacob Hollister   59   41    5.4   349         0      8.5   3    22    0
# Benjamin Watson   24   17    2.4   173         0     10.2   0    26    0
# Travis Kelce     136   97    8.5  1229         2     12.7   5    47    1
# Delanie Walker    31   21    4.4   215         0     10.2   2    29    1
# George Kittle    107   85    7.6  1053         3     12.4   5    61    1
#
#                  FUML  ...  TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  \
# NAME                   ...
# Jacob Hollister     0  ...      19.5      17.0        13.0           39.5
# Benjamin Watson     0  ...      50.0      45.5        46.0           39.5
# Travis Kelce        1  ...       1.0       1.0         2.5            6.0
# Delanie Walker      0  ...      40.5      41.5        23.0           39.5
# George Kittle       0  ...       4.0       4.0         4.0            3.0
#
#                  YDS/REC_rank  TD_rank  LONG_rank  FUM_rank  FUML_rank  \
# NAME
# Jacob Hollister          54.5     25.5       56.5      21.5       27.0
# Benjamin Watson          37.5     61.5       44.5      21.5       27.0
# Travis Kelce             10.5     10.0       15.5      52.0       58.5
# Delanie Walker           37.5     38.5       39.0      52.0       27.0
# George Kittle            13.0     10.0        5.0      52.0       27.0
#
#                  overall
# NAME
# Jacob Hollister    30.25
# Benjamin Watson    42.05
# Travis Kelce       15.80
# Delanie Walker     38.15
# George Kittle      12.50
#
# [5 rows x 21 columns]

# %%
tes = tes[['YDS', 'YDS_rank']]

# %%
tes = tes.sort_values('YDS_rank')

# %%
tes.to_csv('../Capstone_csv_file/tes_yds_rank_19-20')
