# %% [markdown]
# # Tightends Tgt/G Rank

# %%
import pandas as pd

# %%
tes = pd.read_csv('../Capstone_csv_file/tes_stats_rank_17-18', index_col = 'NAME')

# %%
tes.head()
# Out:
#                 TGT  REC  TGT/G  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Rob Gronkowski  105   69    7.5         3    204.7   8    53    1     0
# Greg Olsen       38   17    5.4         1     60.9   1    30    0     0
# Travis Kelce    122   83    8.1         4    177.0   8    44    0     0
# Jimmy Graham     95   57    5.9         0    123.8  10    33    0     0
# Delanie Walker  111   74    6.9         0    173.9   3    42    2     2
#
#                 TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME
# Rob Gronkowski       6.0       5.0         4.0            2.0           2.0
# Greg Olsen          34.0      44.5        12.5            7.0          60.0
# Travis Kelce         1.0       1.0         1.0            1.0          11.0
# Jimmy Graham         7.0       9.5         7.0           38.5          32.0
# Delanie Walker       3.0       3.5         6.0           38.5          12.0
#
# ...

# %%
tes = tes[['TGT/G', 'TGT/G_rank']]

# %%
tes = tes.sort_values('TGT/G_rank')

# %%
tes.to_csv('../Capstone_csv_file/tes_tgt_g_rank_17-18')
