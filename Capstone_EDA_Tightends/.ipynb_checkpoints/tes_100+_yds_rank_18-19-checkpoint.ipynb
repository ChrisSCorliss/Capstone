# %% [markdown]
# # Tightends 100+ Yds Rank

# %%
import pandas as pd

# %%
tes = pd.read_csv('../Capstone_csv_file/tes_stats_rank_18-19', index_col = 'NAME')

# %%
tes.head()
# Out:
#                   TGT  REC  TGT/G  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Demetrius Harris   25   12    1.7         0     13.7   3    35    0     0
# Hayden Hurst       23   13    1.9         0     12.5   1    32    0     0
# Dan Arnold         19   12    1.9         0     12.5   1    25    1     0
# Vance McDonald     73   50    4.9         1     12.2   4    75    2     1
# Anthony Firkser    20   19    2.0         0     11.8   1    28    0     0
#
#                   TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME
# Demetrius Harris      48.0      58.5        51.5           37.5           7.0
# Hayden Hurst          52.0      55.5        48.5           37.5          16.0
# Dan Arnold            58.0      58.5        48.5           37.5          16.0
# Vance McDonald        12.0      12.0        14.0            9.0          18.5
# Anthony Firkser       55.0      47.0        46.5           37.5          22.5
#
# ...

# %%
tes = tes[['100+ YDS', '100+ YDS_rank']]

# %%
tes = tes.sort_values('100+ YDS_rank')

# %%
tes.to_csv('../Capstone_csv_file/tes_100+_yds_rank_18-19')
