# %% [markdown]
# # Tightends EDA

# %%
import pandas as pd

# %%
tes = pd.read_csv('../Capstone_Scrapping/Capstone_text_files/tight_end_18-19.txt')

# %%
tes
# Out:
#                  NAME  RTG TEAM  GP  TGT  REC  TGT/G  YDS  100+ YDS  YDS/REC  \
# 0    Jermaine Gresham   78  ARI  13   12    9    0.9   94         0     10.4
# 1          Ben Koyack   75  JAX   7    0    0    0.0    0         0      0.0
# 2    Demetrius Harris   76   KC  15   25   12    1.7  164         0     13.7
# 3     Jacob Hollister   69   NE   8    5    4    0.6   52         0     13.0
# 4        Hayden Hurst   80  BAL  12   23   13    1.9  163         0     12.5
# ..                ...  ...  ...  ..  ...  ...    ...  ...       ...      ...
# 125    Chris Manhertz   75  CAR  16    5    2    0.3   52         0     26.0
# 126     Hakeem Valles   60  DET   3    3    2    1.0   11         0      5.5
# 127       Sean Culkin   60  LAC  13    1    1    0.1   24         0     24.0
# 128   Darrell Daniels   60  ARI  11    2    0    0.2    0         0      0.0
# 129    Antony Auclair   60   TB  16    8    7    0.5   48         0      6.9
#
#      TD  LONG  FUM  FUML
# 0     0    26    1     1
# 1     0     0    0     0
# 2     3    35    0     0
# 3     0    23    0     0
# 4     1    32    0     0
# ..   ..   ...  ...   ...
# 125   1    50    0     0
# 126   0     6    0     0
# 127   0    24    0     0
# 128   0     0    0     0
# 129   0    12    0     0
#
# [130 rows x 14 columns]

# %%
tes['YDS'] = tes['YDS'].str.replace(',', '').astype('int64')

# %%
tes.rename(columns=lambda x: x.strip(), inplace = True)

# %%
tes = tes[tes['TGT'] > 16].copy()

# %%
tes
# Out:
#                     NAME  RTG TEAM  GP  TGT  REC  TGT/G  YDS  100+ YDS  \
# 2       Demetrius Harris   76   KC  15   25   12    1.7  164         0
# 4           Hayden Hurst   80  BAL  12   23   13    1.9  163         0
# 12            Dan Arnold   69   NO  10   19   12    1.9  150         0
# 21        Vance McDonald   84  PIT  15   73   50    4.9  610         1
# 32       Anthony Firkser   68  TEN  10   20   19    2.0  225         0
# ..                   ...  ...  ...  ..  ...  ...    ...  ...       ...
# 113           Ian Thomas   71  CAR  16   49   36    3.1  333         0
# 116     Chris Herndon IV   66  NYJ  14   56   39    4.0  502         0
# 118  James O'Shaughnessy   77  JAX  14   38   24    2.7  214         0
# 120          Jason Croom   75  BUF  15   35   22    2.3  259         0
# 121         Logan Thomas   62  BUF  12   17   12    1.4   77         0
#
#      YDS/REC  TD  LONG  FUM  FUML
# 2       13.7   3    35    0     0
# 4       12.5   1    32    0     0
# 12      12.5   1    25    1     0
# 21      12.2   4    75    2     1
# 32      11.8   1    28    0     0
# ..       ...  ..   ...  ...   ...
# 113      9.2   2    31    0     0
# 116     12.9   4    32    2     0
# 118      8.9   0    17    0     0
# 120     11.8   1    26    2     2
# 121      6.4   0    24    0     0
#
# [62 rows x 14 columns]

# %%
tes = tes.groupby('NAME', sort = False).mean()

# %%
tes.drop(columns = ['RTG', 'GP'], axis = 1, inplace = True)

# %%
tes_stats = tes.copy()

# %%
tes_rank = {}

# %%
tes_rank['YDS_rank'] = tes['YDS'].rank(ascending = False)

# %%
tes_rank['TGT_rank'] = tes['TGT'].rank(ascending = False)

# %%
tes_rank['REC_rank'] = tes['REC'].rank(ascending = False)

# %%
tes_rank['TGT/G_rank'] = tes['TGT/G'].rank(ascending = False)

# %%
tes_rank['100+ YDS_rank'] = tes['100+ YDS'].rank(ascending = False)

# %%
tes_rank['YDS/REC_rank'] = tes['YDS/REC'].rank(ascending = False)

# %%
tes_rank['TD_rank'] = tes['TD'].rank(ascending = False)

# %%
tes_rank['LONG_rank'] = tes['LONG'].rank(ascending = False)

# %%
tes_rank['FUM_rank'] = tes['FUM'].rank()

# %%
tes_rank['FUML_rank'] = tes['FUML'].rank()

# %%
tes_rank['overall'] = (tes_rank['TGT_rank'] + tes_rank['REC_rank'] + tes_rank['TGT/G_rank'] + tes_rank['100+ YDS_rank'] +
            tes_rank['YDS/REC_rank'] + tes_rank['TD_rank'] + tes_rank['LONG_rank'] +
            tes_rank['FUM_rank'] + tes_rank['FUML_rank'] + tes_rank['YDS_rank'])/10

# %%
tes_rank = pd.DataFrame(tes_rank)

# %%
tes_final_rank = {}

# %%
tes_final_rank['final_rank'] = tes_rank['overall'].rank()

# %%
tes_final_rank = pd.DataFrame(tes_final_rank)

# %%
tes_final_rank = tes_final_rank.sort_values('final_rank')

# %%
tes_final_rank.to_csv('../Capstone_csv_file/tes_final_rank_18-19')

# %%
tes_final_rank
# Out:
#                 final_rank
# NAME
# George Kittle          1.0
# Jared Cook             2.0
# Jimmy Graham           3.0
# Travis Kelce           4.0
# Zach Ertz              5.0
# ...                    ...
# Mike Gesicki          58.0
# Charles Clay          59.0
# Dalton Schultz        60.0
# Logan Thomas          61.0
# Luke Willson          62.0
#
# [62 rows x 1 columns]

# %%
tes = tes_stats.merge(tes_rank, on = 'NAME')

# %%
tes.to_csv('../Capstone_csv_file/tes_stats_rank_18-19')
