# %% [markdown]
# # Tightends Tgt/G Rank

# %%
import pandas as pd

# %%
tes = pd.read_csv('../Capstone_csv_file/tes_stats_rank_19-20', index_col = 'NAME')

# %%
tes.head()
# Out:
#                  TGT  REC  TGT/G  100+ YDS  YDS/REC  TD  LONG  FUM  FUML  \
# NAME
# Jacob Hollister   59   41    5.4         0      8.5   3    22    0     0
# Benjamin Watson   24   17    2.4         0     10.2   0    26    0     0
# Travis Kelce     136   97    8.5         2     12.7   5    47    1     1
# Delanie Walker    31   21    4.4         0     10.2   2    29    1     0
# George Kittle    107   85    7.6         3     12.4   5    61    1     0
#
#                  TGT_rank  REC_rank  TGT/G_rank  100+ YDS_rank  YDS/REC_rank  \
# NAME
# Jacob Hollister      19.5      17.0        13.0           39.5          54.5
# Benjamin Watson      50.0      45.5        46.0           39.5          37.5
# Travis Kelce          1.0       1.0         2.5            6.0          10.5
# Delanie Walker       40.5      41.5        23.0           39.5          37.5
# George Kittle         4.0       4.0         4.0            3.0          13.0
#
# ...

# %%
tes = tes[['TGT/G', 'TGT/G_rank']]

# %%
tes = tes.sort_values('TGT/G_rank')

# %%
tes.to_csv('../Capstone_csv_file/tes_tgt_g_rank_19-20')
