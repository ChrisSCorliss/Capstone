# %% [markdown]
# # Quarterback 300+ Yds Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Nick Mullens     176  274   34.2  2,277         2  64.2%      8.3      12.9
# Matt Barkley      15   25   25.0    232         0    60%      9.3      15.5
# Josh Johnson      52   91   22.8    590         0  57.1%      6.5      11.3
# Jameis Winston   244  378   34.4  2,992         5  64.6%      7.9      12.3
# Derek Anderson    42   70   35.0    465         0    60%      6.6      11.1
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Nick Mullens    13   10  ...        26.5           7.0            6.5
# Matt Barkley     2    0  ...        42.5           2.0            1.0
# Josh Johnson     3    4  ...        48.0          42.0           22.5
# Jameis Winston  19   14  ...        24.0          13.0           10.5
# Derek Anderson   0    4  ...        42.5          39.0           28.5
#
# ...

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['300+ YDS', '300+ YDS_rank']].copy()

# %%
qbs = qbs.sort_values('300+ YDS_rank')

# %%
qbs
# Out:
#                     300+ YDS  300+ YDS_rank
# NAME
# Patrick Mahomes           10            1.0
# Ben Roethlisberger         8            3.0
# Jared Goff                 8            3.0
# Matt Ryan                  8            3.0
# Andrew Luck                7            5.0
# Drew Brees                 6            6.0
# Deshaun Watson             5           10.0
# Jameis Winston             5           10.0
# Kirk Cousins               5           10.0
# Carson Wentz               5           10.0
# Eli Manning                5           10.0
# Tom Brady                  5           10.0
# Philip Rivers              5           10.0
# Derek Carr                 4           16.0
# Blake Bortles              4           16.0
# Aaron Rodgers              4           16.0
# Ryan Fitzpatrick           4           16.0
# Mitch Trubisky             4           16.0
# Cam Newton                 3           20.5
# Matthew Stafford           3           20.5
# ...

# %%
qbs.to_csv('../Capstone_csv_file/qbs_300+_yds_rank_18-19')
