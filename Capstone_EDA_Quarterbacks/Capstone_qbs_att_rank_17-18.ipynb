# %% [markdown]
# # Quarterback Att Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_17-18', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Tom Brady        385  581   36.3  4,577         6  66.3%      7.9      11.9
# Aaron Rodgers    154  238   34.0  1,675         3  64.7%      7.0      10.9
# Russell Wilson   339  553   34.6  3,983         3  61.3%      7.2      11.7
# Drew Brees       386  536   33.5  4,334         3    72%      8.1      11.2
# Matt Ryan        342  529   33.1  4,095         4  64.7%      7.7      12.0
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Tom Brady       32    8  ...        12.0          10.5           12.0
# Aaron Rodgers   16    6  ...        14.5          22.5           38.5
# Russell Wilson  34   11  ...        32.5          20.0           16.5
# Drew Brees      23    8  ...         4.0           5.5           30.0
# Matt Ryan       20   12  ...        14.5          13.0            9.5
#
# ...

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['ATT', 'ATT_rank']].copy()

# %%
qbs = qbs.sort_values('ATT_rank')

# %%
qbs
# Out:
#                     ATT  ATT_rank
# NAME
# Tom Brady           581       1.0
# Philip Rivers       575       2.0
# Eli Manning         571       3.0
# Matthew Stafford    565       4.0
# Ben Roethlisberger  561       5.0
# Russell Wilson      553       6.0
# Joe Flacco          549       7.0
# Kirk Cousins        540       8.0
# Drew Brees          536       9.0
# Matt Ryan           529      10.0
# Blake Bortles       523      11.0
# Derek Carr          515      12.0
# Alex Smith          505      13.0
# Andy Dalton         496      14.0
# Cam Newton          492      15.0
# Dak Prescott        490      16.0
# Case Keenum         481      17.0
# Jared Goff          477      18.0
# Deshone Kizer       476      19.0
# Jacoby Brissett     469      20.0
# Marcus Mariota      453      21.0
# Jameis Winston      442      22.0
# Carson Wentz        440      23.0
# Jay Cutler          429      24.0
# Tyrod Taylor        420      25.0
# Josh McCown         397      26.0
# ...

# %%
qbs.to_csv('../Capstone_csv_file/qbs_att_rank_17-18')
