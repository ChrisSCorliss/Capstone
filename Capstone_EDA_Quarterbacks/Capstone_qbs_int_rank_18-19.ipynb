# %% [markdown]
# # Quarterback INT Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G   YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Nick Mullens     176  274   34.2  2277         2   64.2      8.3      12.9
# Matt Barkley      15   25   25.0   232         0   60.0      9.3      15.5
# Josh Johnson      52   91   22.8   590         0   57.1      6.5      11.3
# Jameis Winston   244  378   34.4  2992         5   64.6      7.9      12.3
# Derek Anderson    42   70   35.0   465         0   60.0      6.6      11.1
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Nick Mullens    13   10  ...        26.5           7.0            6.5
# Matt Barkley     2    0  ...        42.5           2.0            1.0
# Josh Johnson     3    4  ...        48.0          42.0           22.5
# Jameis Winston  19   14  ...        24.0          13.0           10.5
# Derek Anderson   0    4  ...        42.5          39.0           28.5
#
# ...

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['INT', 'INT_rank']].copy()

# %%
qbs = qbs.sort_values('INT_rank')

# %%
qbs.to_csv('../Capstone_csv_file/qbs_int_rank_18-19')

# %%
qbs
# Out:
#                     INT  INT_rank
# NAME
# Matt Barkley          0       1.5
# Kyle Allen            0       1.5
# Teddy Bridgewater     1       3.0
# Tyrod Taylor          2       6.5
# Jeff Driskel          2       6.5
# Aaron Rodgers         2       6.5
# Cody Kessler          2       6.5
# Deshone Kizer         2       6.5
# Chase Daniel          2       6.5
# Taylor Heinicke       3      12.0
# Jimmy Garoppolo       3      12.0
# Lamar Jackson         3      12.0
# Mark Sanchez          3      12.0
# Colt McCoy            3      12.0
# Nick Foles            4      18.0
# Josh McCown           4      18.0
# Sam Bradford          4      18.0
# Derek Anderson        4      18.0
# Brock Osweiler        4      18.0
# Josh Johnson          4      18.0
# Blaine Gabbert        4      18.0
# Alex Smith            5      22.5
# Drew Brees            5      22.5
# Joe Flacco            6      24.0
# CJ Beathard           7      27.0
# Nathan Peterman       7      27.0
# ...
