# %% [markdown]
# # Quarterback Long Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_19-20', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                  COMP  ATT  ATT/G   YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Luke Falk          47   73   24.3   416         0   64.4      5.7       8.9
# Brandon Allen      39   84   28.0   515         0   46.4      6.1      13.2
# Drew Lock         100  156   31.2  1020         1   64.1      6.5      10.2
# Devlin Hodges     100  160   20.0  1063         0   62.5      6.6      10.6
# Patrick Mahomes   319  484   34.6  4031         7   65.9      8.3      12.6
#
#                  TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                      ...
# Luke Falk         0    3  ...        21.5          49.5           53.0
# Brandon Allen     3    2  ...        56.0          46.0            5.0
# Drew Lock         7    3  ...        24.0          40.5           46.0
# Devlin Hodges     5    8  ...        28.5          37.0           41.0
# Patrick Mahomes  26    5  ...        14.0           5.0            7.5
#
# ...

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['LONG', 'LONG_rank']].copy()

# %%
qbs = qbs.sort_values('LONG_rank')

# %%
qbs.to_csv('../Capstone_csv_file/qbs_long_rank_19-20')

# %%
qbs
# Out:
#                     LONG  LONG_rank
# NAME
# Matt Ryan             93        1.0
# Sam Darnold           92        2.0
# Ryan Tannehill        91        3.0
# Baker Mayfield        89        4.0
# Kyler Murray          88        5.0
# Philip Rivers         84        6.0
# Patrick Mahomes       83        7.5
# Lamar Jackson         83        7.5
# Devlin Hodges         79        9.0
# Mason Rudolph         76       10.0
# Daniel Jones          75       14.0
# Derek Carr            75       14.0
# Jimmy Garoppolo       75       14.0
# David Blough          75       14.0
# Dwayne Haskins        75       14.0
# Marcus Mariota        75       14.0
# Brandon Allen         75       14.0
# Aaron Rodgers         74       18.0
# Jameis Winston        71       19.0
# Joe Flacco            70       20.5
# Gardner Minshew       70       20.5
# Case Keenum           69       22.0
# Jared Goff            66       24.5
# Kirk Cousins          66       24.5
# Andy Dalton           66       24.5
# ...
