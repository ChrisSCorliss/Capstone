# %% [markdown]
# # Quarterback Comp Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Nick Mullens     176  274   34.2  2,277         2  64.2%      8.3      12.9
# Matt Barkley      15   25   25.0    232         0    60%      9.3      15.5
# Josh Johnson      52   91   22.8    590         0  57.1%      6.5      11.3
# Jameis Winston   244  378   34.4  2,992         5  64.6%      7.9      12.3
# Derek Anderson    42   70   35.0    465         0    60%      6.6      11.1
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Nick Mullens    13   10  ...        26.5           7.0            6.5
# Matt Barkley     2    0  ...        42.5           2.0            1.0
# Josh Johnson     3    4  ...        48.0          42.0           22.5
# Jameis Winston  19   14  ...        24.0          13.0           10.5
# Derek Anderson   0    4  ...        42.5          39.0           28.5
#
#                 TD_rank  INT_rank  QBR_rank  LONG_rank  SACKS_rank  \
# NAME
# Nick Mullens       27.5      35.0      17.0        4.0        33.0
# Matt Barkley       46.0       1.5      49.0       42.5        54.0
# Josh Johnson       42.0      18.0      29.0        9.0        42.0
# Jameis Winston     21.5      50.0      25.0       31.5        21.0
# Derek Anderson     54.0      18.0      52.0       47.0        49.5
#
#                 SACK YDS_rank  FUML_rank
# NAME
# Nick Mullens             32.0        8.5
# Matt Barkley             53.5        8.5
# Josh Johnson             41.0        8.5
# Jameis Winston           24.5       40.0
# Derek Anderson           50.5       31.0
#
# [5 rows x 30 columns]

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['COMP', 'COMP_rank']].copy()

# %%
qbs = qbs.sort_values('COMP_rank')

# %%
qbs
# Out:
#                     COMP  COMP_rank
# NAME
# Ben Roethlisberger   452        1.0
# Andrew Luck          430        2.0
# Kirk Cousins         425        3.0
# Matt Ryan            422        4.0
# Patrick Mahomes      383        5.0
# Derek Carr           381        6.0
# Eli Manning          380        7.0
# Tom Brady            375        8.0
# Aaron Rodgers        372        9.0
# Matthew Stafford     367       10.0
# Case Keenum          365       11.0
# Jared Goff           364       12.5
# Drew Brees           364       12.5
# Dak Prescott         356       14.0
# Philip Rivers        347       15.0
# Deshaun Watson       345       16.0
# Cam Newton           320       17.0
# Baker Mayfield       310       18.0
# Mitch Trubisky       289       19.0
# Russell Wilson       280       20.0
# Carson Wentz         279       21.0
# Jameis Winston       244       22.0
# Blake Bortles        243       23.0
# Sam Darnold          239       24.0
# Joe Flacco           232       25.0
# Marcus Mariota       228       26.0
# Andy Dalton          226       27.0
# Josh Rosen           217       28.0
# Alex Smith           205       29.0
# Ryan Tannehill       176       30.5
# Nick Mullens         176       30.5
# Josh Allen           169       32.0
# Ryan Fitzpatrick     164       33.0
# Nick Foles           141       34.0
# Brock Osweiler       113       35.0
# Jeff Driskel         105       36.0
# CJ Beathard          102       37.0
# Lamar Jackson         99       38.0
# Cody Kessler          85       39.0
# Blaine Gabbert        61       40.0
# Josh McCown           60       41.0
# Chase Daniel          53       42.5
# Jimmy Garoppolo       53       42.5
# Josh Johnson          52       44.0
# Sam Bradford          50       45.0
# Nathan Peterman       44       46.0
# Derek Anderson        42       47.5
# Tyrod Taylor          42       47.5
# Taylor Heinicke       35       49.0
# Colt McCoy            34       50.0
# Deshone Kizer         20       51.5
# Kyle Allen            20       51.5
# Mark Sanchez          19       53.0
# Matt Barkley          15       54.0
# Teddy Bridgewater     14       55.0

# %%
qbs.to_csv('../Capstone_csv_file/qbs_comp_rank_18-19')
