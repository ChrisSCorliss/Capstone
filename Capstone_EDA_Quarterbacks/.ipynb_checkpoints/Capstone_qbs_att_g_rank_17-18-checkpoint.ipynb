# %% [markdown]
# # Quarterback Att/G Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_17-18', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Tom Brady        385  581   36.3  4,577         6  66.3%      7.9      11.9
# Aaron Rodgers    154  238   34.0  1,675         3  64.7%      7.0      10.9
# Russell Wilson   339  553   34.6  3,983         3  61.3%      7.2      11.7
# Drew Brees       386  536   33.5  4,334         3    72%      8.1      11.2
# Matt Ryan        342  529   33.1  4,095         4  64.7%      7.7      12.0
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Tom Brady       32    8  ...        12.0          10.5           12.0
# Aaron Rodgers   16    6  ...        14.5          22.5           38.5
# Russell Wilson  34   11  ...        32.5          20.0           16.5
# Drew Brees      23    8  ...         4.0           5.5           30.0
# Matt Ryan       20   12  ...        14.5          13.0            9.5
#
#                 TD_rank  INT_rank  QBR_rank  LONG_rank  SACKS_rank  \
# NAME
# Tom Brady           3.0      37.0       2.0       26.5        10.0
# Aaron Rodgers      24.0      27.5      30.0       17.0        26.0
# Russell Wilson      1.0      42.5       7.5       14.5         4.0
# Drew Brees         11.0      37.0       1.0       34.5        31.0
# Matt Ryan          17.0      45.0      12.0        3.0        22.5
#
#                 SACK YDS_rank  FUML_rank
# NAME
# Tom Brady                14.0       45.0
# Aaron Rodgers            21.0       24.5
# Russell Wilson            2.0       45.0
# Drew Brees               28.0        9.0
# Matt Ryan                24.0       45.0
#
# [5 rows x 30 columns]

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['ATT/G', 'ATT/G_rank']].copy()

# %%
qbs = qbs.sort_values('ATT/G_rank')

# %%
qbs
# Out:
#                     ATT/G  ATT/G_rank
# NAME
# Carson Palmer        38.1         1.5
# Eli Manning          38.1         1.5
# Ben Roethlisberger   37.4         3.0
# Tom Brady            36.3         4.0
# Philip Rivers        35.9         5.0
# Matthew Stafford     35.3         6.0
# Mike Glennon         35.0         7.5
# Patrick Mahomes      35.0         7.5
# Russell Wilson       34.6         9.0
# Joe Flacco           34.3        10.5
# Derek Carr           34.3        10.5
# Blaine Gabbert       34.2        12.0
# Jameis Winston       34.0        13.5
# Aaron Rodgers        34.0        13.5
# Carson Wentz         33.8        15.5
# Kirk Cousins         33.8        15.5
# Alex Smith           33.7        17.0
# Drew Brees           33.5        18.0
# Matt Ryan            33.1        19.0
# Blake Bortles        32.7        20.0
# Case Keenum          32.1        21.0
# CJ Beathard          32.0        22.0
# Drew Stanton         31.8        24.0
# Jared Goff           31.8        24.0
# Matt Moore           31.8        24.0
# Deshone Kizer        31.7        26.5
# Trevor Siemian       31.7        26.5
# Andy Dalton          31.0        28.0
# Cam Newton           30.8        29.0
# Dak Prescott         30.6        30.5
# Jay Cutler           30.6        30.5
# Josh McCown          30.5        32.0
# Marcus Mariota       30.2        33.0
# Jimmy Garoppolo      29.7        34.0
# Jacoby Brissett      29.3        35.0
# Deshaun Watson       29.1        36.0
# Brock Osweiler       28.7        37.5
# Brett Hundley        28.7        37.5
# Bryce Petty          28.0        39.5
# Tyrod Taylor         28.0        39.5
# Tom Savage           27.9        41.0
# Mitch Trubisky       27.5        42.0
# Ryan Fitzpatrick     27.2        43.0
# TJ Yates             24.2        44.0
# Nate Sudfeld         23.0        45.0
# Paxton Lynch         22.5        46.0
# Sam Bradford         21.5        48.0
# EJ Manuel            21.5        48.0
# David Fales          21.5        48.0
# Brian Hoyer          19.2        50.0
# Kevin Hogan          18.8        51.0
# Geno Smith           18.0        52.0
# Nick Foles           14.4        53.0
# Matt Cassel          14.0        54.0
# Nathan Peterman      12.2        55.0
# Landry Jones          9.3        56.0
# Cody Kessler          7.7        57.0
# Sean Mannion          7.4        58.0

# %%
qbs.to_csv('../Capstone_csv_file/qbs_att_g_rank_17-18')
