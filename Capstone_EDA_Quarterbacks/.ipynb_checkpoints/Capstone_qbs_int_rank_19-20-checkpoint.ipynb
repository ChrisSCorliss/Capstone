# %% [markdown]
# # Quarterback INT Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_19-20', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                  COMP  ATT  ATT/G   YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Luke Falk          47   73   24.3   416         0   64.4      5.7       8.9
# Brandon Allen      39   84   28.0   515         0   46.4      6.1      13.2
# Drew Lock         100  156   31.2  1020         1   64.1      6.5      10.2
# Devlin Hodges     100  160   20.0  1063         0   62.5      6.6      10.6
# Patrick Mahomes   319  484   34.6  4031         7   65.9      8.3      12.6
#
#                  TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                      ...
# Luke Falk         0    3  ...        21.5          49.5           53.0
# Brandon Allen     3    2  ...        56.0          46.0            5.0
# Drew Lock         7    3  ...        24.0          40.5           46.0
# Devlin Hodges     5    8  ...        28.5          37.0           41.0
# Patrick Mahomes  26    5  ...        14.0           5.0            7.5
#
#                  TD_rank  INT_rank  QBR_rank  LONG_rank  SACKS_rank  \
# NAME
# Luke Falk           53.0      15.0      32.0       50.0        32.5
# Brandon Allen       44.5      10.0      47.0       14.0        42.0
# Drew Lock           34.0      15.0       9.0       40.0        50.5
# Devlin Hodges       38.0      38.0      36.0        9.0        35.0
# Patrick Mahomes     10.0      25.0      12.0        7.5        31.0
#
#                  SACK YDS_rank  FUML_rank
# NAME
# Luke Falk                 36.0       19.0
# Brandon Allen             43.0        7.5
# Drew Lock                 52.0       19.0
# Devlin Hodges             34.0       19.0
# Patrick Mahomes           31.0       29.0
#
# [5 rows x 30 columns]

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['INT', 'INT_rank']].copy()

# %%
qbs = qbs.sort_values('INT_rank')

# %%
qbs.to_csv('../Capstone_csv_file/qbs_int_rank_19-20')

# %%
qbs
# Out:
#                     INT  INT_rank
# NAME
# Matt Moore            0       1.0
# Colt McCoy            1       4.0
# AJ McCarron           1       4.0
# Cam Newton            1       4.0
# Matt Schaub           1       4.0
# Ben Roethlisberger    1       4.0
# Teddy Bridgewater     2      10.0
# Brandon Allen         2      10.0
# Chase Daniel          2      10.0
# Ryan Finley           2      10.0
# Robert Griffin III    2      10.0
# Nick Foles            2      10.0
# Marcus Mariota        2      10.0
# Matt Barkley          3      15.0
# Luke Falk             3      15.0
# Drew Lock             3      15.0
# Aaron Rodgers         4      19.0
# Jeff Driskel          4      19.0
# Drew Brees            4      19.0
# Will Grier            4      19.0
# Brian Hoyer           4      19.0
# Case Keenum           5      25.0
# Patrick Mahomes       5      25.0
# Matthew Stafford      5      25.0
# Joe Flacco            5      25.0
# Josh Rosen            5      25.0
# Eli Manning           5      25.0
# Russell Wilson        5      25.0
# Lamar Jackson         6      31.5
# Jacoby Brissett       6      31.5
# David Blough          6      31.5
# Kirk Cousins          6      31.5
# Gardner Minshew       6      31.5
# Ryan Tannehill        6      31.5
# Dwayne Haskins        7      35.5
# Carson Wentz          7      35.5
# Derek Carr            8      38.0
# Tom Brady             8      38.0
# Devlin Hodges         8      38.0
# Josh Allen            9      40.5
# Mason Rudolph         9      40.5
# Mitch Trubisky       10      42.0
# Dak Prescott         11      43.0
# Kyler Murray         12      45.0
# Deshaun Watson       12      45.0
# Daniel Jones         12      45.0
# Sam Darnold          13      48.0
# Ryan Fitzpatrick     13      48.0
# Jimmy Garoppolo      13      48.0
# Andy Dalton          14      51.0
# Jared Goff           14      51.0
# Matt Ryan            14      51.0
# Kyle Allen           16      53.0
# Philip Rivers        20      54.0
# Baker Mayfield       21      55.0
# Jameis Winston       30      56.0
