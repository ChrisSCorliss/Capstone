# %% [markdown]
# # Quarterback Att Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_19-20', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                  COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Luke Falk          47   73   24.3    416         0  64.4%      5.7       8.9
# Brandon Allen      39   84   28.0    515         0  46.4%      6.1      13.2
# Drew Lock         100  156   31.2  1,020         1  64.1%      6.5      10.2
# Devlin Hodges     100  160   20.0  1,063         0  62.5%      6.6      10.6
# Patrick Mahomes   319  484   34.6  4,031         7  65.9%      8.3      12.6
#
#                  TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                      ...
# Luke Falk         0    3  ...        21.5          49.5           53.0
# Brandon Allen     3    2  ...        56.0          46.0            5.0
# Drew Lock         7    3  ...        24.0          40.5           46.0
# Devlin Hodges     5    8  ...        28.5          37.0           41.0
# Patrick Mahomes  26    5  ...        14.0           5.0            7.5
#
#                  TD_rank  INT_rank  QBR_rank  LONG_rank  SACKS_rank  \
# NAME
# Luke Falk           53.0      15.0      32.0       50.0        32.5
# Brandon Allen       44.5      10.0      47.0       14.0        42.0
# Drew Lock           34.0      15.0       9.0       40.0        50.5
# Devlin Hodges       38.0      38.0      36.0        9.0        35.0
# Patrick Mahomes     10.0      25.0      12.0        7.5        31.0
#
#                  SACK YDS_rank  FUML_rank
# NAME
# Luke Falk                 36.0       19.0
# Brandon Allen             43.0        7.5
# Drew Lock                 52.0       19.0
# Devlin Hodges             34.0       19.0
# Patrick Mahomes           31.0       29.0
#
# [5 rows x 30 columns]

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['ATT', 'ATT_rank']].copy()

# %%
qbs = qbs.sort_values('ATT_rank')

# %%
qbs
# Out:
#                     ATT  ATT_rank
# NAME
# Jameis Winston      626       1.0
# Matt Ryan           616       2.0
# Tom Brady           613       3.0
# Carson Wentz        607       4.0
# Dak Prescott        596       5.0
# Philip Rivers       591       6.0
# Jared Goff          589       7.0
# Aaron Rodgers       569       8.0
# Kyler Murray        542       9.0
# Baker Mayfield      534      10.0
# Andy Dalton         528      11.0
# Mitch Trubisky      516      12.5
# Russell Wilson      516      12.5
# Derek Carr          513      14.0
# Ryan Fitzpatrick    502      15.0
# Deshaun Watson      495      16.0
# Kyle Allen          489      17.0
# Patrick Mahomes     484      18.0
# Jimmy Garoppolo     476      19.0
# Gardner Minshew     470      20.0
# Josh Allen          461      21.0
# Daniel Jones        459      22.0
# Jacoby Brissett     447      23.0
# Kirk Cousins        444      24.0
# Sam Darnold         441      25.0
# Lamar Jackson       381      26.0
# Drew Brees          378      27.0
# Matthew Stafford    291      28.0
# Ryan Tannehill      286      29.0
# Mason Rudolph       283      30.0
# Joe Flacco          262      31.0
# Case Keenum         247      32.0
# Dwayne Haskins      203      33.0
# Teddy Bridgewater   196      34.0
# David Blough        174      35.0
# Devlin Hodges       160      36.5
# Marcus Mariota      160      36.5
# Drew Lock           156      38.0
# Eli Manning         147      39.0
# Nick Foles          117      40.0
# Josh Rosen          109      41.0
# Jeff Driskel        105      42.0
# Matt Moore           91      43.0
# Cam Newton           89      44.0
# Ryan Finley          87      45.0
# Brandon Allen        84      46.0
# Luke Falk            73      47.0
# Matt Schaub          67      48.0
# Brian Hoyer          65      49.0
# Chase Daniel         64      50.0
# Ben Roethlisberger   62      51.0
# Will Grier           52      52.0
# Matt Barkley         51      53.0
# AJ McCarron          37      54.0
# Robert Griffin III   35      55.0
# Colt McCoy           27      56.0

# %%
qbs.to_csv('../Capstone_csv_file/qbs_att_rank_19-20')
