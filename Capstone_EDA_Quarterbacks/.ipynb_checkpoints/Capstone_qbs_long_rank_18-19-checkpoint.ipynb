# %% [markdown]
# # Quarterback Long Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G   YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Nick Mullens     176  274   34.2  2277         2   64.2      8.3      12.9
# Matt Barkley      15   25   25.0   232         0   60.0      9.3      15.5
# Josh Johnson      52   91   22.8   590         0   57.1      6.5      11.3
# Jameis Winston   244  378   34.4  2992         5   64.6      7.9      12.3
# Derek Anderson    42   70   35.0   465         0   60.0      6.6      11.1
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Nick Mullens    13   10  ...        26.5           7.0            6.5
# Matt Barkley     2    0  ...        42.5           2.0            1.0
# Josh Johnson     3    4  ...        48.0          42.0           22.5
# Jameis Winston  19   14  ...        24.0          13.0           10.5
# Derek Anderson   0    4  ...        42.5          39.0           28.5
#
#                 TD_rank  INT_rank  QBR_rank  LONG_rank  SACKS_rank  \
# NAME
# Nick Mullens       27.5      35.0      17.0        4.0        33.0
# Matt Barkley       46.0       1.5      49.0       42.5        54.0
# Josh Johnson       42.0      18.0      29.0        9.0        42.0
# Jameis Winston     21.5      50.0      25.0       31.5        21.0
# Derek Anderson     54.0      18.0      52.0       47.0        49.5
#
#                 SACK YDS_rank  FUML_rank
# NAME
# Nick Mullens             32.0        8.5
# Matt Barkley             53.5        8.5
# Josh Johnson             41.0        8.5
# Jameis Winston           24.5       40.0
# Derek Anderson           50.5       31.0
#
# [5 rows x 30 columns]

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['LONG', 'LONG_rank']].copy()

# %%
qbs = qbs.sort_values('LONG_rank')

# %%
qbs.to_csv('../Capstone_csv_file/qbs_long_rank_18-19')

# %%
qbs
# Out:
#                     LONG  LONG_rank
# NAME
# Ben Roethlisberger    97        1.0
# Dak Prescott          90        2.0
# Patrick Mahomes       89        3.0
# Nick Mullens          85        4.0
# Nick Foles            83        5.0
# CJ Beathard           82        6.5
# Cam Newton            82        6.5
# Blake Bortles         80        8.0
# Josh Johnson          79        9.0
# Sam Darnold           76       10.0
# Kirk Cousins          75       15.0
# Ryan Tannehill        75       15.0
# Philip Rivers         75       15.0
# Matt Ryan             75       15.0
# Josh Rosen            75       15.0
# Ryan Fitzpatrick      75       15.0
# Aaron Rodgers         75       15.0
# Brock Osweiler        75       15.0
# Josh Allen            75       15.0
# Lamar Jackson         74       20.0
# Deshaun Watson        73       21.0
# Drew Brees            72       22.0
# Baker Mayfield        71       23.5
# Joe Flacco            71       23.5
# Jared Goff            70       25.5
# Mitch Trubisky        70       25.5
# Andrew Luck           68       27.0
# Matthew Stafford      67       28.0
# Derek Carr            66       29.5
# Russell Wilson        66       29.5
# Jameis Winston        64       31.5
# Case Keenum           64       31.5
# Tom Brady             63       33.0
# Marcus Mariota        61       34.0
# Carson Wentz          58       35.5
# Eli Manning           58       35.5
# Jimmy Garoppolo       56       37.0
# Colt McCoy            53       38.5
# Kyle Allen            53       38.5
# Alex Smith            52       40.0
# Andy Dalton           49       41.0
# Tyrod Taylor          47       42.5
# Matt Barkley          47       42.5
# Chase Daniel          46       44.5
# Jeff Driskel          46       44.5
# Josh McCown           41       46.0
# Derek Anderson        40       47.0
# Cody Kessler          35       49.0
# Sam Bradford          35       49.0
# Blaine Gabbert        35       49.0
# Taylor Heinicke       33       51.0
# Deshone Kizer         29       52.0
# Nathan Peterman       26       53.0
# Mark Sanchez          20       54.0
# Teddy Bridgewater     18       55.0
