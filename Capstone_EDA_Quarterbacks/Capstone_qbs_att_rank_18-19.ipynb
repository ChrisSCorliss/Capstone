# %% [markdown]
# # Quarterback Att Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Nick Mullens     176  274   34.2  2,277         2  64.2%      8.3      12.9
# Matt Barkley      15   25   25.0    232         0    60%      9.3      15.5
# Josh Johnson      52   91   22.8    590         0  57.1%      6.5      11.3
# Jameis Winston   244  378   34.4  2,992         5  64.6%      7.9      12.3
# Derek Anderson    42   70   35.0    465         0    60%      6.6      11.1
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Nick Mullens    13   10  ...        26.5           7.0            6.5
# Matt Barkley     2    0  ...        42.5           2.0            1.0
# Josh Johnson     3    4  ...        48.0          42.0           22.5
# Jameis Winston  19   14  ...        24.0          13.0           10.5
# Derek Anderson   0    4  ...        42.5          39.0           28.5
#
# ...

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['ATT', 'ATT_rank']].copy()

# %%
qbs = qbs.sort_values('ATT_rank')

# %%
qbs
# Out:
#                     ATT  ATT_rank
# NAME
# Ben Roethlisberger  675       1.0
# Andrew Luck         639       2.0
# Matt Ryan           608       3.0
# Kirk Cousins        606       4.0
# Aaron Rodgers       597       5.0
# Case Keenum         586       6.0
# Patrick Mahomes     580       7.0
# Eli Manning         576       8.0
# Tom Brady           570       9.0
# Jared Goff          561      10.0
# Matthew Stafford    555      11.0
# Derek Carr          553      12.0
# Dak Prescott        526      13.0
# Philip Rivers       508      14.0
# Deshaun Watson      505      15.0
# Drew Brees          489      16.0
# Baker Mayfield      486      17.0
# Cam Newton          471      18.0
# Mitch Trubisky      434      19.0
# Russell Wilson      427      20.0
# Sam Darnold         414      21.0
# Blake Bortles       403      22.0
# Carson Wentz        401      23.0
# Josh Rosen          393      24.0
# Joe Flacco          379      25.0
# Jameis Winston      378      26.0
# ...

# %%
qbs.to_csv('../Capstone_csv_file/qbs_att_rank_18-19')
