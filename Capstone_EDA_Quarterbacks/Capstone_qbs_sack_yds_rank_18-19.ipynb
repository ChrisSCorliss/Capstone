# %% [markdown]
# # Quarterback Sacks Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G   YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Nick Mullens     176  274   34.2  2277         2   64.2      8.3      12.9
# Matt Barkley      15   25   25.0   232         0   60.0      9.3      15.5
# Josh Johnson      52   91   22.8   590         0   57.1      6.5      11.3
# Jameis Winston   244  378   34.4  2992         5   64.6      7.9      12.3
# Derek Anderson    42   70   35.0   465         0   60.0      6.6      11.1
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Nick Mullens    13   10  ...        26.5           7.0            6.5
# Matt Barkley     2    0  ...        42.5           2.0            1.0
# Josh Johnson     3    4  ...        48.0          42.0           22.5
# Jameis Winston  19   14  ...        24.0          13.0           10.5
# Derek Anderson   0    4  ...        42.5          39.0           28.5
#
# ...

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['SACK YDS', 'SACK YDS_rank']].copy()

# %%
qbs = qbs.sort_values('SACK YDS_rank')

# %%
qbs.to_csv('../Capstone_csv_file/qbs_sack_yds_rank_18-19')

# %%
qbs
# Out:
#                     SACK YDS  SACK YDS_rank
# NAME
# Kyle Allen                 0            1.0
# Matt Barkley               8            2.5
# Teddy Bridgewater          8            2.5
# Taylor Heinicke           17            4.0
# Sam Bradford              33            5.5
# Derek Anderson            33            5.5
# Nathan Peterman           34            7.0
# Josh McCown               35            8.0
# Colt McCoy                36            9.0
# Blaine Gabbert            37           10.0
# Deshone Kizer             38           11.0
# Chase Daniel              40           12.0
# Mark Sanchez              42           13.0
# Nick Foles                47           14.0
# Josh Johnson              67           15.0
# Lamar Jackson             73           16.0
# Ryan Fitzpatrick          76           17.0
# Joe Flacco                79           18.0
# Tyrod Taylor              81           19.0
# Jimmy Garoppolo           97           20.0
# ...
