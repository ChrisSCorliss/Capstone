# %% [markdown]
# # Quarterback Comp Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_19-20', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                  COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Luke Falk          47   73   24.3    416         0  64.4%      5.7       8.9
# Brandon Allen      39   84   28.0    515         0  46.4%      6.1      13.2
# Drew Lock         100  156   31.2  1,020         1  64.1%      6.5      10.2
# Devlin Hodges     100  160   20.0  1,063         0  62.5%      6.6      10.6
# Patrick Mahomes   319  484   34.6  4,031         7  65.9%      8.3      12.6
#
#                  TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                      ...
# Luke Falk         0    3  ...        21.5          49.5           53.0
# Brandon Allen     3    2  ...        56.0          46.0            5.0
# Drew Lock         7    3  ...        24.0          40.5           46.0
# Devlin Hodges     5    8  ...        28.5          37.0           41.0
# Patrick Mahomes  26    5  ...        14.0           5.0            7.5
#
#                  TD_rank  INT_rank  QBR_rank  LONG_rank  SACKS_rank  \
# NAME
# Luke Falk           53.0      15.0      32.0       50.0        32.5
# Brandon Allen       44.5      10.0      47.0       14.0        42.0
# Drew Lock           34.0      15.0       9.0       40.0        50.5
# Devlin Hodges       38.0      38.0      36.0        9.0        35.0
# Patrick Mahomes     10.0      25.0      12.0        7.5        31.0
#
#                  SACK YDS_rank  FUML_rank
# NAME
# Luke Falk                 36.0       19.0
# Brandon Allen             43.0        7.5
# Drew Lock                 52.0       19.0
# Devlin Hodges             34.0       19.0
# Patrick Mahomes           31.0       29.0
#
# [5 rows x 30 columns]

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['COMP', 'COMP_rank']].copy()

# %%
qbs = qbs.sort_values('COMP_rank')

# %%
qbs
# Out:
#                     COMP  COMP_rank
# NAME
# Matt Ryan            408        1.0
# Philip Rivers        390        2.0
# Carson Wentz         388        3.5
# Dak Prescott         388        3.5
# Jameis Winston       380        5.0
# Tom Brady            373        6.0
# Jared Goff           368        7.0
# Derek Carr           361        8.0
# Aaron Rodgers        353        9.0
# Kyler Murray         349       10.0
# Russell Wilson       341       11.0
# Deshaun Watson       333       12.0
# Jimmy Garoppolo      329       13.0
# Mitch Trubisky       326       14.0
# Patrick Mahomes      319       15.0
# Baker Mayfield       317       16.0
# Andy Dalton          314       17.0
# Ryan Fitzpatrick     311       18.0
# Kirk Cousins         307       19.0
# Kyle Allen           303       20.0
# Gardner Minshew      285       21.0
# Daniel Jones         284       22.0
# Drew Brees           281       23.0
# Sam Darnold          273       24.0
# Jacoby Brissett      272       25.0
# Josh Allen           271       26.0
# Lamar Jackson        250       27.0
# Ryan Tannehill       201       28.0
# Matthew Stafford     187       29.0
# Mason Rudolph        176       30.0
# Joe Flacco           171       31.0
# Case Keenum          160       32.0
# Teddy Bridgewater    133       33.0
# Dwayne Haskins       119       34.0
# Devlin Hodges        100       35.5
# Drew Lock            100       35.5
# Marcus Mariota        95       37.0
# David Blough          94       38.0
# Eli Manning           91       39.0
# Nick Foles            77       40.0
# Jeff Driskel          62       41.0
# Matt Moore            59       42.0
# Josh Rosen            58       43.0
# Cam Newton            50       44.5
# Matt Schaub           50       44.5
# Luke Falk             47       46.0
# Chase Daniel          45       47.0
# Ryan Finley           41       48.0
# Brandon Allen         39       49.0
# Brian Hoyer           35       50.5
# Ben Roethlisberger    35       50.5
# Will Grier            28       52.0
# Matt Barkley          27       53.0
# Robert Griffin III    22       54.0
# AJ McCarron           21       55.0
# Colt McCoy            18       56.0

# %%
qbs.to_csv('../Capstone_csv_file/qbs_comp_rank_19-20')
