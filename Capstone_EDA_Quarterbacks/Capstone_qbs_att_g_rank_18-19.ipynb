# %% [markdown]
# # Quarterback Att/G Rank

# %%
import pandas as pd

# %%
qbs = pd.read_csv('../Capstone_csv_file/qbs_stats_rank_18-19', index_col = 'NAME')

# %%
qbs.head()
# Out:
#                 COMP  ATT  ATT/G    YDS  300+ YDS  COMP%  YDS/ATT  YDS/COMP  \
# NAME
# Nick Mullens     176  274   34.2  2,277         2  64.2%      8.3      12.9
# Matt Barkley      15   25   25.0    232         0    60%      9.3      15.5
# Josh Johnson      52   91   22.8    590         0  57.1%      6.5      11.3
# Jameis Winston   244  378   34.4  2,992         5  64.6%      7.9      12.3
# Derek Anderson    42   70   35.0    465         0    60%      6.6      11.1
#
#                 TD  INT  ...  COMP%_rank  YDS/ATT_rank  YDS/COMP_rank  \
# NAME                     ...
# Nick Mullens    13   10  ...        26.5           7.0            6.5
# Matt Barkley     2    0  ...        42.5           2.0            1.0
# Josh Johnson     3    4  ...        48.0          42.0           22.5
# Jameis Winston  19   14  ...        24.0          13.0           10.5
# Derek Anderson   0    4  ...        42.5          39.0           28.5
#
# ...

# %%
qbs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
qbs = qbs[['ATT/G', 'ATT/G_rank']].copy()

# %%
qbs = qbs.sort_values('ATT/G_rank')

# %%
qbs
# Out:
#                     ATT/G  ATT/G_rank
# NAME
# Ben Roethlisberger   42.2         1.0
# Joe Flacco           42.1         2.0
# Andrew Luck          39.9         3.0
# Nick Foles           39.0         4.0
# Matt Ryan            38.0         5.0
# Kirk Cousins         37.9         6.0
# Aaron Rodgers        37.3         7.0
# Case Keenum          36.6         8.0
# Carson Wentz         36.5         9.0
# Patrick Mahomes      36.2        10.0
# Eli Manning          36.0        11.0
# Tom Brady            35.6        12.0
# Jared Goff           35.1        13.0
# Derek Anderson       35.0        14.0
# Baker Mayfield       34.7        15.5
# Matthew Stafford     34.7        15.5
# Derek Carr           34.6        17.0
# Jameis Winston       34.4        18.0
# Nick Mullens         34.2        19.0
# Cam Newton           33.6        20.0
# Andy Dalton          33.2        21.0
# Dak Prescott         32.9        22.0
# Alex Smith           32.8        23.0
# ...

# %%
qbs.to_csv('../Capstone_csv_file/qbs_att_g_rank_18-19')
