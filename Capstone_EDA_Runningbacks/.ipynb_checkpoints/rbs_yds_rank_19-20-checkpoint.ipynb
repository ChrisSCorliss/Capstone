# %% [markdown]
# # Runningbacks Yds Rank

# %%
import pandas as pd

# %%
rbs = pd.read_csv('../Capstone_csv_file/rbs_stats_rank_19-20', index_col = 'NAME')

# %%
rbs.head()
# Out:
#                ATT  YDS  YDS/ATT  ATT/G  100+ YDS  TD  LONG  FUM  FUML  \
# NAME
# Spencer Ware    17   51      3.0    5.7         0   0     6    1     0
# Trey Edmunds    22   92      4.2    2.0         0   0    45    0     0
# Tra Carson      18   48      2.7    6.0         0   0    12    0     0
# Bo Scarbrough   89  377      4.2   14.8         0   1    30    1     1
# Boston Scott    61  245      4.0    5.5         0   5    25    4     1
#
#                YDS_rank  ATT_rank  YDS/ATT_rank  ATT/G_rank  100+ YDS_rank  \
# NAME
# Spencer Ware       95.0      96.0          91.5        55.5           68.5
# Trey Edmunds       89.0      90.5          47.0        93.5           68.5
# Tra Carson         97.0      93.5          94.0        54.0           68.5
# Bo Scarbrough      48.0      47.0          47.0        17.5           68.5
# Boston Scott       59.5      60.0          53.5        57.0           68.5
#
#                TD_rank  LONG_rank  FUM_rank  FUML_rank
# NAME
# ...

# %%
rbs = rbs[['YDS', 'YDS_rank']].copy()

# %%
rbs = rbs.sort_values('YDS_rank')

# %%
rbs
# Out:
#                       YDS  YDS_rank
# NAME
# Derrick Henry        1540       1.0
# Nick Chubb           1494       2.0
# Christian McCaffrey  1387       3.0
# Ezekiel Elliott      1357       4.0
# Chris Carson         1230       5.0
# ...                   ...       ...
# Darren Sproles         66      93.0
# TJ Yeldon              63      94.0
# Spencer Ware           51      95.0
# Qadree Ollison         50      96.0
# Tra Carson             48      97.0
#
# [97 rows x 2 columns]

# %%
rbs.to_csv('../Capstone_csv_file/rbs_yds_rank_19-20')
