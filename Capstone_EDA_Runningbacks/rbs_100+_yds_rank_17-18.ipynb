# %% [markdown]
# # Runningbacks 100+ yds Rank

# %%
import pandas as pd

# %%
rbs = pd.read_csv('../Capstone_csv_file/rbs_stats_rank_17-18', index_col = 'NAME')

# %%
rbs.head()
# Out:
#                  ATT  YDS/ATT  ATT/G  100+ YDS  TD  LONG  FUM  FUML  ATT_rank  \
# NAME
# Le'Veon Bell     321     59.5   21.4         4   9    27    3     2       1.0
# Ezekiel Elliott  242     38.2   24.2         5   7    30    1     1      10.0
# Todd Gurley      279     70.5   18.6         6  13    57    5     2       4.0
# Kareem Hunt      272    106.0   17.0         6   8    69    1     1       6.0
# LeSean McCoy     287     61.9   17.9         4   6    48    3     1       2.0
#
#                  YDS/ATT_rank  ATT/G_rank  100+ YDS_rank  TD_rank  LONG_rank  \
# NAME
# Le'Veon Bell             31.5         2.0            7.0      4.0       60.0
# Ezekiel Elliott          64.0         1.0            4.0     12.0       55.5
# Todd Gurley              11.0         4.0            1.5      1.0       23.0
# Kareem Hunt               1.0         9.0            1.5      8.0       12.0
# LeSean McCoy             22.0         6.0            7.0     16.0       29.5
#
# ...

# %%
rbs = rbs[['100+ YDS', '100+ YDS_rank']].copy()

# %%
rbs = rbs.sort_values('100+ YDS_rank')

# %%
rbs
# Out:
#                    100+ YDS  100+ YDS_rank
# NAME
# Todd Gurley               6            1.5
# Kareem Hunt               6            1.5
# Ezekiel Elliott           5            4.0
# Jordan Howard             5            4.0
# Leonard Fournette         5            4.0
# ...                     ...            ...
# Marlon Mack               0           68.5
# Thomas Rawls              0           68.5
# Branden Oliver            0           68.5
# Jalen Richard             0           68.5
# Tion Green                0           68.5
#
# [98 rows x 2 columns]

# %%
rbs.to_csv('../Capstone_csv_file/rbs_100+_yds_rank_17-18')
