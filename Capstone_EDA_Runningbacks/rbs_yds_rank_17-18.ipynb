# %% [markdown]
# # Runningbacks Yds Rank

# %%
import pandas as pd

# %%
rbs = pd.read_csv('../Capstone_csv_file/rbs_stats_rank_17-18', index_col = 'NAME')

# %%
rbs.head()
# Out:
#                  ATT   YDS  YDS/ATT  ATT/G  100+ YDS  TD  LONG  FUM  FUML  \
# NAME
# Le'Veon Bell     321  1291     59.5   21.4         4   9    27    3     2
# Ezekiel Elliott  242   983     38.2   24.2         5   7    30    1     1
# Todd Gurley      279  1305     70.5   18.6         6  13    57    5     2
# Kareem Hunt      272  1327    106.0   17.0         6   8    69    1     1
# LeSean McCoy     287  1138     61.9   17.9         4   6    48    3     1
#
#                  YDS_rank  ATT_rank  YDS/ATT_rank  ATT/G_rank  100+ YDS_rank  \
# NAME
# Le'Veon Bell          3.0       1.0          31.5         2.0            7.0
# Ezekiel Elliott      10.0      10.0          64.0         1.0            4.0
# Todd Gurley           2.0       4.0          11.0         4.0            1.5
# Kareem Hunt           1.0       6.0           1.0         9.0            1.5
# LeSean McCoy          4.0       2.0          22.0         6.0            7.0
#
# ...

# %%
rbs = rbs[['YDS', 'YDS_rank']].copy()

# %%
rbs = rbs.sort_values('YDS_rank')

# %%
rbs
# Out:
#                     YDS  YDS_rank
# NAME
# Kareem Hunt        1327       1.0
# Todd Gurley        1305       2.0
# Le'Veon Bell       1291       3.0
# LeSean McCoy       1138       4.0
# Mark Ingram        1124       5.0
# ...                 ...       ...
# Kapri Bibbs          79      94.0
# Charcandrick West    72      95.0
# Andre Ellington      55      96.0
# Robert Turbin        53      97.0
# Dwayne Washington    44      98.0
#
# [98 rows x 2 columns]

# %%
rbs.to_csv('../Capstone_csv_file/rbs_yds_rank_17-18')
