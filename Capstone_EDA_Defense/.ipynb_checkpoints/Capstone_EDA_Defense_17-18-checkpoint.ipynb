# %% [markdown]
# # EDA of Defensive Statistics

# %%
import pandas as pd

# %%
defs = pd.read_csv('../Capstone_Scrapping/Capstone_text_files/defense_17-18.txt')

# %%
defs.head()
# Out:
#                 NAME  RTG TEAM  GP  TCKL  SOLO  AST   TFL  SCK  SCK YDS  QBH  \
# 0     Blake Martinez   76   GB  16   145    96   49  11.5  1.0        0    2
# 1      Preston Brown   76  BUF  16   144    84   60   7.5  0.0        0    2
# 2       Joe Schobert   78  CLE  16   141    85   56   6.5  3.0        0    7
# 3  Christian Kirksey   73  CLE  16   139    87   52   9.5  3.5        0    6
# 4        Deion Jones   88  ATL  16   138    91   47  11.5  1.0        0    0
#
#    PASS DEF  FF  FUMR  FUMR YDS  FUMR TD  INT  INT YDS  INT TD
# 0         8   1     2         0        0    1        3       0
# 1         3   0     0         0        0    0        0       0
# 2         3   2     0         0        0    1        8       0
# 3         5   2     1         0        0    0        0       0
# 4        10   1     0         0        0    3       42       0

# %%
defs.rename(columns=lambda x: x.strip(), inplace = True)

# %%
defs_1 = defs.drop(['RTG', 'TEAM', 'GP'], axis = 1)

# %%
defs_1.head()
# Out:
#                 NAME  TCKL  SOLO  AST   TFL  SCK  SCK YDS  QBH  PASS DEF  FF  \
# 0     Blake Martinez   145    96   49  11.5  1.0        0    2         8   1
# 1      Preston Brown   144    84   60   7.5  0.0        0    2         3   0
# 2       Joe Schobert   141    85   56   6.5  3.0        0    7         3   2
# 3  Christian Kirksey   139    87   52   9.5  3.5        0    6         5   2
# 4        Deion Jones   138    91   47  11.5  1.0        0    0        10   1
#
#    FUMR  FUMR YDS  FUMR TD  INT  INT YDS  INT TD
# 0     2         0        0    1        3       0
# 1     0         0        0    0        0       0
# 2     0         0        0    1        8       0
# 3     1         0        0    0        0       0
# 4     0         0        0    3       42       0

# %%
defs_1['TCKL_rank'] = defs_1['TCKL'].rank(ascending = False)

# %%
defs_1['SOLO_rank'] = defs_1['SOLO'].rank(ascending = False)

# %%
defs_1['AST_rank'] = defs_1['AST'].rank(ascending = False)

# %%
defs_1['TFL_rank'] = defs_1['TFL'].rank(ascending = False)

# %%
defs_1['SCK_rank'] = defs_1['SCK'].rank(ascending = False)

# %%
defs_1['SCK YDS_rank'] = defs_1['SCK YDS'].rank(ascending = False)

# %%
defs_1['QBH_rank'] = defs_1['QBH'].rank(ascending = False)

# %%
defs_1['PASS DEF_rank'] = defs_1['PASS DEF'].rank(ascending = False)

# %%
defs_1['FF_rank'] = defs_1['FF'].rank(ascending = False)

# %%
defs_1['FUMR_rank'] = defs_1['FUMR'].rank(ascending = False)

# %%
defs_1['FUMR YDS_rank'] = defs_1['FUMR YDS'].rank(ascending = False)

# %%
defs_1['FUMR TD_rank'] = defs_1['FUMR TD'].rank(ascending = False)

# %%
defs_1['INT_rank'] = defs_1['INT'].rank(ascending = False)

# %%
defs_1['INT YDS_rank'] = defs_1['INT YDS'].rank(ascending = False)

# %%
defs_1['INT TD_rank'] = defs_1['INT TD'].rank(ascending = False)

# %%
defs_1
# Out:
#                   NAME  TCKL  SOLO  AST   TFL  SCK  SCK YDS  QBH  PASS DEF  \
# 0       Blake Martinez   145    96   49  11.5  1.0        0    2         8
# 1        Preston Brown   144    84   60   7.5  0.0        0    2         3
# 2         Joe Schobert   141    85   56   6.5  3.0        0    7         3
# 3    Christian Kirksey   139    87   52   9.5  3.5        0    6         5
# 4          Deion Jones   138    91   47  11.5  1.0        0    0        10
# ..                 ...   ...   ...  ...   ...  ...      ...  ...       ...
# 195      Rodney McLeod    54    39   15   2.0  0.0        0    0         6
# 196        Ken Crawley    54    47    7   1.0  0.0        0    0        17
# 197      Mike Mitchell    54    36   18   1.0  0.0        0    1         2
# 198           AJ Klein    54    37   17   6.0  2.0        0    3         4
# 199     Jaquiski Tartt    54    37   17   4.0  0.5        0    2         3
#
#      FF  ...  SCK YDS_rank  QBH_rank  PASS DEF_rank  FF_rank  FUMR_rank  \
# 0     1  ...         100.5      98.5           50.0     72.0       15.0
# 1     0  ...         100.5      98.5          138.0    153.0      139.0
# 2     2  ...         100.5      31.0          138.0     24.5      139.0
# 3     2  ...         100.5      37.0          100.5     24.5       51.5
# 4     1  ...         100.5     173.5           31.5     72.0      139.0
# ..   ..  ...           ...       ...            ...      ...        ...
# 195   1  ...         100.5     173.5           77.0     72.0       15.0
# 196   0  ...         100.5     173.5            7.0    153.0      139.0
# 197   0  ...         100.5     132.0          161.0    153.0       51.5
# 198   1  ...         100.5      70.0          118.5     72.0      139.0
# 199   0  ...         100.5      98.5          138.0    153.0      139.0
#
#      FUMR YDS_rank  FUMR TD_rank  INT_rank  INT YDS_rank  INT TD_rank
# 0            107.5         108.5      90.0          88.5        110.5
# 1            107.5         108.5     158.0         147.0        110.5
# 2            107.5         108.5      90.0          80.5        110.5
# 3            107.5         108.5     158.0         147.0        110.5
# 4            107.5         108.5      26.0          33.0        110.5
# ..             ...           ...       ...           ...          ...
# 195            7.0         108.5      26.0          18.0        110.5
# 196          107.5         108.5      90.0         147.0        110.5
# 197          107.5         108.5     158.0         147.0        110.5
# 198          107.5         108.5     158.0         147.0        110.5
# 199          107.5         108.5      90.0          39.0        110.5
#
# [200 rows x 31 columns]

# %%
defs_1_rank = defs_1.drop(['TCKL', 'SOLO', 'AST', 'TFL', 'SCK', 'SCK YDS', 
             'QBH', 'PASS DEF', 'FF', 'FUMR', 'FUMR YDS', 'FUMR TD',
             'INT', 'INT YDS', 'INT TD'], axis = 1)

# %%
defs_1_rank.head()
# Out:
#                 NAME  TCKL_rank  SOLO_rank  AST_rank  TFL_rank  SCK_rank  \
# 0     Blake Martinez        1.0        4.0       4.5      25.5      91.5
# 1      Preston Brown        2.0       10.0       1.0      53.0     159.5
# 2       Joe Schobert        3.0        8.0       2.0      68.0      33.0
# 3  Christian Kirksey        4.0        7.0       3.0      35.0      28.5
# 4        Deion Jones        5.0        6.0       7.5      25.5      91.5
#
#    SCK YDS_rank  QBH_rank  PASS DEF_rank  FF_rank  FUMR_rank  FUMR YDS_rank  \
# 0         100.5      98.5           50.0     72.0       15.0          107.5
# 1         100.5      98.5          138.0    153.0      139.0          107.5
# 2         100.5      31.0          138.0     24.5      139.0          107.5
# 3         100.5      37.0          100.5     24.5       51.5          107.5
# 4         100.5     173.5           31.5     72.0      139.0          107.5
#
#    FUMR TD_rank  INT_rank  INT YDS_rank  INT TD_rank
# 0         108.5      90.0          88.5        110.5
# 1         108.5     158.0         147.0        110.5
# 2         108.5      90.0          80.5        110.5
# 3         108.5     158.0         147.0        110.5
# 4         108.5      26.0          33.0        110.5

# %%
defs_1_rank.columns
# Out:
# Index(['NAME', 'TCKL_rank', 'SOLO_rank', 'AST_rank', 'TFL_rank', 'SCK_rank',
#        'SCK YDS_rank', 'QBH_rank', 'PASS DEF_rank', 'FF_rank', 'FUMR_rank',
#        'FUMR YDS_rank', 'FUMR TD_rank', 'INT_rank', 'INT YDS_rank',
#        'INT TD_rank'],
#       dtype='object')

# %%
defs_1_rank_avg = defs_1_rank.groupby('NAME', sort = False).mean()

# %%
defs_1_rank_avg
# Out:
#                    TCKL_rank  SOLO_rank  AST_rank  TFL_rank  SCK_rank  \
# NAME
# Blake Martinez           1.0        4.0       4.5      25.5      91.5
# Preston Brown            2.0       10.0       1.0      53.0     159.5
# Joe Schobert             3.0        8.0       2.0      68.0      33.0
# Christian Kirksey        4.0        7.0       3.0      35.0      28.5
# Deion Jones              5.0        6.0       7.5      25.5      91.5
# ...                      ...        ...       ...       ...       ...
# Rodney McLeod          194.5      184.0     132.5     162.5     159.5
# Ken Crawley            194.5      150.5     191.0     182.5     159.5
# Mike Mitchell          194.5      195.5     108.0     182.5     159.5
# AJ Klein               194.5      193.0     116.0      77.0      48.5
# Jaquiski Tartt         194.5      193.0     116.0     119.5     116.5
#
#                    SCK YDS_rank  QBH_rank  PASS DEF_rank  FF_rank  FUMR_rank  \
# NAME
# Blake Martinez            100.5      98.5           50.0     72.0       15.0
# Preston Brown             100.5      98.5          138.0    153.0      139.0
# Joe Schobert              100.5      31.0          138.0     24.5      139.0
# Christian Kirksey         100.5      37.0          100.5     24.5       51.5
# Deion Jones               100.5     173.5           31.5     72.0      139.0
# ...                         ...       ...            ...      ...        ...
# Rodney McLeod             100.5     173.5           77.0     72.0       15.0
# Ken Crawley               100.5     173.5            7.0    153.0      139.0
# Mike Mitchell             100.5     132.0          161.0    153.0       51.5
# AJ Klein                  100.5      70.0          118.5     72.0      139.0
# Jaquiski Tartt            100.5      98.5          138.0    153.0      139.0
#
#                    FUMR YDS_rank  FUMR TD_rank  INT_rank  INT YDS_rank  \
# NAME
# Blake Martinez             107.5         108.5      90.0          88.5
# Preston Brown              107.5         108.5     158.0         147.0
# Joe Schobert               107.5         108.5      90.0          80.5
# Christian Kirksey          107.5         108.5     158.0         147.0
# Deion Jones                107.5         108.5      26.0          33.0
# ...                          ...           ...       ...           ...
# Rodney McLeod                7.0         108.5      26.0          18.0
# Ken Crawley                107.5         108.5      90.0         147.0
# Mike Mitchell              107.5         108.5     158.0         147.0
# AJ Klein                   107.5         108.5     158.0         147.0
# Jaquiski Tartt             107.5         108.5      90.0          39.0
#
#                    INT TD_rank
# NAME
# Blake Martinez           110.5
# Preston Brown            110.5
# Joe Schobert             110.5
# Christian Kirksey        110.5
# Deion Jones              110.5
# ...                        ...
# Rodney McLeod            110.5
# Ken Crawley              110.5
# Mike Mitchell            110.5
# AJ Klein                 110.5
# Jaquiski Tartt           110.5
#
# [200 rows x 15 columns]

# %%
defs_1_rank_avg['overall'] = (defs_1_rank_avg['TCKL_rank'] + defs_1_rank_avg['SOLO_rank'] + defs_1_rank_avg['AST_rank'] + defs_1_rank_avg['TFL_rank'] +
defs_1_rank_avg['SCK_rank'] + defs_1_rank_avg['SCK YDS_rank'] + defs_1_rank_avg['QBH_rank'] + defs_1_rank_avg['PASS DEF_rank'] +
defs_1_rank_avg['FF_rank'] + defs_1_rank_avg['FUMR_rank'] + defs_1_rank_avg['FUMR YDS_rank'] + defs_1_rank_avg['FUMR TD_rank'] +
defs_1_rank_avg['INT_rank'] + defs_1_rank_avg['INT YDS_rank'] + defs_1_rank_avg['INT TD_rank']) / 15

# %%
defs_1_rank_avg
# Out:
#                    TCKL_rank  SOLO_rank  AST_rank  TFL_rank  SCK_rank  \
# NAME
# Blake Martinez           1.0        4.0       4.5      25.5      91.5
# Preston Brown            2.0       10.0       1.0      53.0     159.5
# Joe Schobert             3.0        8.0       2.0      68.0      33.0
# Christian Kirksey        4.0        7.0       3.0      35.0      28.5
# Deion Jones              5.0        6.0       7.5      25.5      91.5
# ...                      ...        ...       ...       ...       ...
# Rodney McLeod          194.5      184.0     132.5     162.5     159.5
# Ken Crawley            194.5      150.5     191.0     182.5     159.5
# Mike Mitchell          194.5      195.5     108.0     182.5     159.5
# AJ Klein               194.5      193.0     116.0      77.0      48.5
# Jaquiski Tartt         194.5      193.0     116.0     119.5     116.5
#
#                    SCK YDS_rank  QBH_rank  PASS DEF_rank  FF_rank  FUMR_rank  \
# NAME
# Blake Martinez            100.5      98.5           50.0     72.0       15.0
# Preston Brown             100.5      98.5          138.0    153.0      139.0
# Joe Schobert              100.5      31.0          138.0     24.5      139.0
# Christian Kirksey         100.5      37.0          100.5     24.5       51.5
# Deion Jones               100.5     173.5           31.5     72.0      139.0
# ...                         ...       ...            ...      ...        ...
# Rodney McLeod             100.5     173.5           77.0     72.0       15.0
# Ken Crawley               100.5     173.5            7.0    153.0      139.0
# Mike Mitchell             100.5     132.0          161.0    153.0       51.5
# AJ Klein                  100.5      70.0          118.5     72.0      139.0
# Jaquiski Tartt            100.5      98.5          138.0    153.0      139.0
#
#                    FUMR YDS_rank  FUMR TD_rank  INT_rank  INT YDS_rank  \
# NAME
# Blake Martinez             107.5         108.5      90.0          88.5
# Preston Brown              107.5         108.5     158.0         147.0
# Joe Schobert               107.5         108.5      90.0          80.5
# Christian Kirksey          107.5         108.5     158.0         147.0
# Deion Jones                107.5         108.5      26.0          33.0
# ...                          ...           ...       ...           ...
# Rodney McLeod                7.0         108.5      26.0          18.0
# Ken Crawley                107.5         108.5      90.0         147.0
# Mike Mitchell              107.5         108.5     158.0         147.0
# AJ Klein                   107.5         108.5     158.0         147.0
# Jaquiski Tartt             107.5         108.5      90.0          39.0
#
#                    INT TD_rank     overall
# NAME
# Blake Martinez           110.5   64.500000
# Preston Brown            110.5   99.066667
# Joe Schobert             110.5   69.600000
# Christian Kirksey        110.5   68.200000
# Deion Jones              110.5   69.166667
# ...                        ...         ...
# Rodney McLeod            110.5  102.733333
# Ken Crawley              110.5  134.300000
# Mike Mitchell            110.5  137.966667
# AJ Klein                 110.5  117.366667
# Jaquiski Tartt           110.5  121.600000
#
# [200 rows x 16 columns]

# %%
defs_overall_rank = {}

# %%
defs_overall_rank['overall'] = defs_1_rank_avg['overall']

# %%
defs_overall_rank = pd.DataFrame(defs_overall_rank)

# %%
defs_overall_rank['final_rank'] = defs_overall_rank['overall'].rank()

# %%
defs_final_overall_rank = defs_overall_rank['final_rank']

# %%
defs_final_overall_rank = pd.DataFrame(defs_final_overall_rank)

# %%
defs_final_overall_rank = defs_final_overall_rank.sort_values('final_rank')

# %%
defs_final_overall_rank
# Out:
#                   final_rank
# NAME
# CJ Mosley                1.0
# Luke Kuechly             2.0
# Telvin Smith             3.0
# Bobby Wagner             4.0
# Wesley Woodyard          5.0
# ...                      ...
# Cory James             196.0
# Jonathan Cyprien       197.0
# Mike Mitchell          198.0
# Ricardo Allen          199.0
# Jabrill Peppers        200.0
#
# [200 rows x 1 columns]

# %%
defs_final_overall_rank.to_csv('../Capstone_csv_file/defense_final_rank_17-18.csv', index = False)
